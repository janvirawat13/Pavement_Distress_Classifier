# %%
from ultralytics import YOLO

# %%
# Load pretrained YOLOv11 nano model
model = YOLO("yolo11n.pt")   # nano (fastest)

# %%
results = model.train(
    data=r"D:\image_classifiction\dataset\data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Ultralytics 8.4.14  Python-3.10.11 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO
model=YOLO("D:\\image_classifiction\\runs\\detect\\train2\\weights\\best.pt")

# %%
result2=model(r"D:\image_classifiction\dataset\valid\images\2217_jpg.rf.ffdcd342c3e0ba377e16a6a4790c575a.jpg",save=True)
result2[0].show()
# Out:
# image 1/1 D:\image_classifiction\dataset\valid\images\2217_jpg.rf.ffdcd342c3e0ba377e16a6a4790c575a.jpg: 640x640 1 latuidue, 29.3ms
# Speed: 11.9ms preprocess, 29.3ms inference, 44.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to D:\image_classifiction\runs\detect\predict7
